# %% [markdown]
# <a href="https://colab.research.google.com/github/vinit1234singh/Ques-Gen/blob/OCR-API/Object_Chracter_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 27.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 27.5 MB/s eta 0:00:00
# ...

# %%
    import easyocr

# %%
    reader = easyocr.Reader(['en']) # 'en' specifies the language (English in this case)
    # You can add multiple languages like ['en', 'ch_sim'] for English and Simplified Chinese
    # To run on CPU: reader = easyocr.Reader(['en'], gpu=False)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
    image_path = 'test1.png'
    result = reader.readtext(image_path)

# %%
    result = reader.readtext(image_path, detail=0)

# %%
    print(result)
    for detection in result:
        if len(detection) == 3:
            bbox, text, score = detection
            print(f"Text: {text}, Confidence: {score}")
# Out:
# ['Requirement already satisfied:', 'torch in', '[local/liblpython3.I1/dist-packages (from easyocr) (2.6.0+Cu124)', 'Requirement already satisfied: torchvision>-0.5 in /usr/local/lib/python3.11/dist-packages (from easyocr) (0.21.0+Cu124)', 'Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from easyocr)', '(4.11.0.86)', 'Requirement already satisfied: scipy in /usr/local/lib/python3.I/dist-packages (from easyocr) (1.15.3)', 'Requirement already satisfied:', 'numpy in', '[usr/local/liblpython3.11/dist-packages (from easyocr) (2.0.2)', 'Requirement already satisfied: Pillow in /usr/local/lib/python3.li/dist-packages (from easyocr) (11.2.1)', 'Requirement already satisfied: scikit-image', 'in', 'lusr', '[local/lib/python3.11/dist-packages (from easyocr)', '(0.25.2)', 'Collecting', 'bidi (from easyocr)', 'Downloading python_bidi-0.6.6-Cp311-cp311-manylinux_', '2 17', 'X86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)', 'Requirement already s
# ...

# %%
pip install flask-restful
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok, conf
conf.get_default().auth_token = "2xRgKn0uPhfO1WF2OnSNOkxae0U_7VRDVMjmofrDCJbXaGCmH"

# %%
from flask import Flask, jsonify
from pyngrok import ngrok, conf

# Set ngrok authtoken (REQUIRED!)
conf.get_default().auth_token = "2xRgKn0uPhfO1WF2OnSNOkxae0U_7VRDVMjmofrDCJbXaGCmH"

# Create Flask app
app = Flask(__name__)

@app.route("/getParsedata", methods=['GET'])
def get_data():
    return jsonify({"message": result})

# Open public tunnel
public_url = ngrok.connect(5000)
print(" * Ngrok tunnel URL:", public_url)

# Start Flask app
app.run(port=5000)
# Out:
#  * Ngrok tunnel URL: NgrokTunnel: "https://9034-35-229-129-145.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# WARNING:pyngrok.process.ngrok:t=2025-05-22T09:36:04+0000 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.equinox.io/check\": context deadline exceeded"
# INFO:werkzeug:127.0.0.1 - - [22/May/2025 09:36:36] "GET /getParsedata HTTP/1.1" 200 -
